# %%
BASE_DIR = "/content/archive.zip"

# %%
zipfile.is_zipfile("/content/archive.zip")  # → False

# %%
import os, zipfile
zip_path = "/content/archive.zip"
print("Exists? ", os.path.exists(zip_path))
print("Is zip?  ", zipfile.is_zipfile(zip_path))

# %%
# Core
import os
import numpy as np
import random

# Image handling
import cv2
from PIL import Image

# Data & metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# TensorFlow / Keras
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet_preprocess

# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

# Reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
torch.manual_seed(SEED)

# Paths & constants
BASE_DIR = "flowers"        # folder that contains daisy/, rose/, etc.
CLASSES  = ["daisy", "dandelion", "rose", "sunflower", "tulip"]
IMG_SIZE = 224              # good for ResNet50
BATCH_SIZE_TF = 32
BATCH_SIZE_PT = 32
EPOCHS = 20

# %%
import os, zipfile
zip_path = "/content/archive.zip"
print("Exists? ", os.path.exists(zip_path))
print("Is zip?  ", zipfile.is_zipfile(zip_path))
# Out:
# Exists?  True
# Is zip?   True

# %%
import zipfile, os, shutil

zip_path = "/content/archive.zip"
extract_path = "/content/flowers"

if os.path.exists(extract_path):
    shutil.rmtree(extract_path)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Top level in /content/flowers:", os.listdir(extract_path))
# Out:
# Top level in /content/flowers: ['flowers']

# %%
['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']
# Out:
# ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %%
import os, zipfile, shutil

zip_path = "/content/archive.zip"      # Kaggle zip
extract_root = "/content/flowers"

# Clean old folder if needed
if os.path.exists(extract_root):
    shutil.rmtree(extract_root)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_root)

print("Top level in /content/flowers:", os.listdir(extract_root))
# Out:
# Top level in /content/flowers: ['flowers']

# %%
import os, cv2, numpy as np
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

IMG_SIZE = 150

# Folder that contains 5 class folders
BASE_DIR = "/content/flowers/flowers"

classes = ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']
print("Classes in dataset:", os.listdir(BASE_DIR))
# Out:
# Classes in dataset: ['rose', 'daisy', 'tulip', 'sunflower', 'dandelion']

# %%
import matplotlib.pyplot as plt

def show_sample_images(base_dir, classes, num_per_class=3):
    plt.figure(figsize=(12, 8))
    idx = 1
    for cls in classes:
        folder = os.path.join(base_dir, cls)
        images = os.listdir(folder)[:num_per_class]
        for img_name in images:
            path = os.path.join(folder, img_name)
            img = cv2.imread(path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            plt.subplot(len(classes), num_per_class, idx)
            plt.imshow(img)
            plt.axis('off')
            if idx <= num_per_class:
                plt.title(cls)
            idx += 1
    plt.tight_layout()
    plt.show()

show_sample_images(BASE_DIR, classes, num_per_class=3)

# %%
X, Z = [], []

def make_train_data(flower_type):
    flower_dir = os.path.join(BASE_DIR, flower_type)
    print("Reading:", flower_dir)
    for img_name in tqdm(os.listdir(flower_dir), desc=flower_type):
        path = os.path.join(flower_dir, img_name)
        img = cv2.imread(path, cv2.IMREAD_COLOR)
        if img is None:
            continue
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        X.append(np.array(img))
        Z.append(flower_type)

for c in classes:
    make_train_data(c)

X = np.array(X, dtype="float32")
print("Total images:", len(X), "   Shape:", X.shape)

# Label encode
le = LabelEncoder()
Y_int = le.fit_transform(Z)  # 0..4
Y = to_categorical(Y_int, num_classes=len(classes))

# 75/25 split
x_train, x_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.25, random_state=42, stratify=Y_int
)

print("Train:", x_train.shape, y_train.shape)
print("Test: ", x_test.shape,  y_test.shape)
# Out:
# Reading: /content/flowers/flowers/daisy
# daisy: 100%|██████████| 764/764 [00:01<00:00, 531.24it/s]
# Reading: /content/flowers/flowers/dandelion
# dandelion: 100%|██████████| 1052/1052 [00:01<00:00, 564.02it/s]
# Reading: /content/flowers/flowers/rose
# rose: 100%|██████████| 784/784 [00:01<00:00, 569.59it/s]
# Reading: /content/flowers/flowers/sunflower
# sunflower: 100%|██████████| 733/733 [00:01<00:00, 441.86it/s]
# Reading: /content/flowers/flowers/tulip
# tulip: 100%|██████████| 984/984 [00:01<00:00, 521.98it/s]
# Total images: 4317    Shape: (4317, 150, 150, 3)
# Train: (3237, 150, 150, 3) (3237, 5)
# Test:  (1080, 150, 150, 3) (1080, 5)

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input

# ResNet50 expects preprocessed inputs
x_train_tf = preprocess_input(x_train.copy())
x_test_tf  = preprocess_input(x_test.copy())

print("x_train_tf shape:", x_train_tf.shape)
print("x_test_tf  shape:", x_test_tf.shape)
# Out:
# x_train_tf shape: (3237, 150, 150, 3)
# x_test_tf  shape: (1080, 150, 150, 3)

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

num_classes = len(classes)

base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# Freeze convolutional base
for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
preds = Dense(num_classes, activation='softmax')(x)

tf_model = Model(inputs=base_model.input, outputs=preds)

tf_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

tf_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 150, 150,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 156, 156,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 75, 75,    │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
es = EarlyStopping(
    monitor='val_accuracy',
    patience=3,
    restore_best_weights=True
)

history = tf_model.fit(
    x_train_tf, y_train,
    validation_split=0.2,
    epochs=20,
    batch_size=32,
    callbacks=[es],
    verbose=1
)
# Out:
# Epoch 1/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 324s 4s/step - accuracy: 0.4962 - loss: 1.4681 - val_accuracy: 0.8071 - val_loss: 0.5258
# Epoch 2/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 314s 4s/step - accuracy: 0.7885 - loss: 0.5567 - val_accuracy: 0.8256 - val_loss: 0.4676
# Epoch 3/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 328s 4s/step - accuracy: 0.8285 - loss: 0.4407 - val_accuracy: 0.8441 - val_loss: 0.4318
# Epoch 4/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 325s 4s/step - accuracy: 0.8792 - loss: 0.3325 - val_accuracy: 0.8457 - val_loss: 0.4216
# Epoch 5/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 327s 4s/step - accuracy: 0.9086 - loss: 0.2801 - val_accuracy: 0.8611 - val_loss: 0.4034
# Epoch 6/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 329s 4s/step - accuracy: 0.9159 - loss: 0.2368 - val_accuracy: 0.8611 - val_loss: 0.3860
# Epoch 7/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 326s 4s/step - accuracy: 0.9260 - loss: 0.2069 - val_accuracy: 0.8642 - val_loss: 0.3900
# Epoch 8/20
# ...

# %%
# Training curves
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.title('TF ResNet50 Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title('TF ResNet50 Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

test_loss, test_acc = tf_model.evaluate(x_test_tf, y_test, verbose=0)
print("TensorFlow Test Accuracy:", test_acc)

# Predictions
y_pred_proba = tf_model.predict(x_test_tf)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test, axis=1)

print("\nTensorFlow Classification Report:")
print(classification_report(y_true, y_pred, target_names=classes))

cm_tf = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm_tf, annot=True, fmt='d',
            xticklabels=classes, yticklabels=classes, cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("TensorFlow Confusion Matrix")
plt.show()
# Out:
# TensorFlow Test Accuracy: 0.8620370626449585
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 106s 3s/step
#
# TensorFlow Classification Report:
#               precision    recall  f1-score   support
#
#        daisy       0.87      0.84      0.85       191
#    dandelion       0.88      0.93      0.90       263
#         rose       0.82      0.80      0.81       196
#    sunflower       0.94      0.86      0.90       184
#        tulip       0.82      0.86      0.84       246
#
#     accuracy                           0.86      1080
#    macro avg       0.87      0.86      0.86      1080
# weighted avg       0.86      0.86      0.86      1080

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

DATA_DIR = BASE_DIR   # "/content/flowers/flowers"

transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std =[0.229, 0.224, 0.225])
])

full_dataset = datasets.ImageFolder(DATA_DIR, transform=transform)
print("PyTorch classes:", full_dataset.classes)
num_classes_pt = len(full_dataset.classes)

# 75/25 split
len_full = len(full_dataset)
len_train = int(0.75 * len_full)
len_test  = len_full - len_train
train_dataset, test_dataset = random_split(full_dataset, [len_train, len_test])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader  = DataLoader(test_dataset,  batch_size=32, shuffle=False)

print("Train size:", len(train_dataset))
print("Test size:", len(test_dataset))
# Out:
# Using device: cpu
# PyTorch classes: ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']
# Train size: 3237
# Test size: 1080

# %%
resnet = models.resnet50(pretrained=True)

# Freeze backbone
for param in resnet.parameters():
    param.requires_grad = False

num_features = resnet.fc.in_features
resnet.fc = nn.Sequential(
    nn.Linear(num_features, 512),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(512, num_classes_pt)
)

resnet = resnet.to(device)
print(resnet.fc)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Sequential(
#   (0): Linear(in_features=2048, out_features=512, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=512, out_features=5, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(resnet.fc.parameters(), lr=1e-4)

EPOCHS = 15
train_losses, train_accs = [], []

for epoch in range(EPOCHS):
    resnet.train()
    running_loss, correct, total = 0.0, 0, 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = resnet(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        _, preds = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (preds == labels).sum().item()

    epoch_loss = running_loss / total
    epoch_acc  = correct / total
    train_losses.append(epoch_loss)
    train_accs.append(epoch_acc)

    print(f"Epoch {epoch+1}/{EPOCHS}  Loss: {epoch_loss:.4f}  Acc: {epoch_acc:.4f}")
# Out:
# Epoch 1/15  Loss: 1.0408  Acc: 0.6395
# Epoch 2/15  Loss: 0.6006  Acc: 0.8001
# Epoch 3/15  Loss: 0.5145  Acc: 0.8251
# Epoch 4/15  Loss: 0.4534  Acc: 0.8431

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.plot(train_losses)
plt.title("PyTorch ResNet50 Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.subplot(1,2,2)
plt.plot(train_accs)
plt.title("PyTorch ResNet50 Training Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.tight_layout()
plt.show()

# %%
resnet.eval()
all_preds, all_labels = [], []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = resnet(images)
        _, preds = torch.max(outputs, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())

all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

acc_pt = accuracy_score(all_labels, all_preds)
print("PyTorch Test Accuracy:", acc_pt)

print("\nPyTorch Classification Report:")
print(classification_report(all_labels, all_preds, target_names=full_dataset.classes))

cm_pt = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(6,5))
sns.heatmap(cm_pt, annot=True, fmt='d',
            xticklabels=full_dataset.classes,
            yticklabels=full_dataset.classes,
            cmap='Greens')
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("PyTorch Confusion Matrix")
plt.show()

# %%
import os
import matplotlib.pyplot as plt

counts = []
for cls in classes:
    folder = os.path.join(BASE_DIR, cls)
    counts.append(len(os.listdir(folder)))

plt.figure(figsize=(6,4))
plt.bar(classes, counts)
plt.title("Number of Images per Class")
plt.xlabel("Flower Class")
plt.ylabel("Count")
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()
